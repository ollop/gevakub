# %%
import sqlite3
import pandas as pd

# Create the connection
cnx = sqlite3.connect(r'./database.sqlite')

# create the dataframe from a query
df_participants = pd.read_sql_query("SELECT * FROM participants", cnx)
df_runs = pd.read_sql_query("SELECT * FROM runs", cnx)
df_positions = pd.read_sql_query("SELECT * FROM positions", cnx)


# remove invalid entries (1-4 = testing, 14 is pid 10 (aborted study)) 
df_runs_filtered = df_runs[(df_runs.participant_id != 1) & (df_runs.participant_id != 2) & (df_runs.participant_id != 3) & (df_runs.participant_id != 4) & (df_runs.participant_id != 14)]

# participant_id 5,6 -> 39 entries
# participant_id 21 -> 37 entries

# %%
df_positions.head()
# Out:
#    id           x          y           z
# 0   1  357.665863  11.297280   10.094984
# 1   2  355.455933   7.994468  354.065216
# 2   3  353.392059   4.533486  356.326111
# 3   4  356.404785   5.901930  355.644470
# 4   5   -0.167264  -1.950000   -2.197365

# %%
# participant_id 5,6 -> 39 entries
# participant_id 21 -> 37 entries
# happens through restarted conditions (because technical problems in a secific conditions)
# but we are only interested in the coordinates of the interactive gestures -> again remove not needed entries

df_runs_filtered = df_runs_filtered[(df_runs_filtered.custom_position_id != 0) | (df_runs_filtered.custom_direction_id != 0)]

# %%
df_runs_filtered.head()
# Out:
#     id  participant_id  custom_position_id  custom_direction_id  \
# 50  51               5                   0                   15
# 51  52               5                   0                   16
# 52  53               5                  17                    0
# 53  54               5                  18                    0
# 62  63               5                  19                    0
#
#    point_of_reference    placement    scenario avatar_gender  \
# 50        FieldOfView  Interactive  Stationary        Female
# 51        FieldOfView  Interactive  Stationary          Male
# 52       FixedInSpace  Interactive      Mobile        Female
# 53       FixedInSpace  Interactive      Mobile          Male
# 62           Relative  Interactive  Stationary          Male
#
#                    started                finished            call_started  \
# 50  2019-1-12 12:32:17.634  2019-1-12 12:33:30.940  2019-1-12 12:32:20.277
# 51  2019-1-12 12:33:32.270  2019-1-12 12:34:27.950  2019-1-12 12:33:33.395
# 52   2019-1-12 12:41:1.801  2019-1-12 12:43:20.339   2019-1-12 12:41:7.908
# 53  2019-1-12 12:43:21.853  2019-1-12 12:44:41.906  2019-1-12 12:43:27.332
# 62  2019-1-12 13:30:24.679  2019-1-12 13:31:48.454  2019-1-12 13:30:27.244
#
#              call_answered
# 50  2019-1-12 12:32:59.689
# 51  2019-1-12 12:33:53.470
# 52  2019-1-12 12:42:50.339
# 53   2019-1-12 12:44:8.675
# 62   2019-1-12 13:31:15.90

# %%
df_runs_filtered.count()
# Out:
# id                     217
# participant_id         217
# custom_position_id     217
# custom_direction_id    217
# point_of_reference     217
# placement              217
# scenario               217
# avatar_gender          217
# started                217
# finished               217
# call_started           217
# call_answered          217
# dtype: int64

# %%
df_runs_filtered.set_index(["id", "participant_id"]).count(level="participant_id")
# Out:
#                 custom_position_id  custom_direction_id  point_of_reference  \
# participant_id
# 5                               12                   12                  12
# 6                               13                   13                  13
# 7                               12                   12                  12
# 8                               12                   12                  12
# 9                               12                   12                  12
# 10                              12                   12                  12
# 11                              12                   12                  12
# 12                              12                   12                  12
# 13                              12                   12                  12
# 15                              12                   12                  12
# 16                              12                   12                  12
# 17                              12                   12                  12
# 18                              12                   12                  12
# 19                              12                   12                  12
# 20                              12                   12                  12
# 21                              12                   12                  12
# 22                              12                   12                  12
# 23                              12                   12                  12
#
#                 placement  scenario  avatar_gender  started  finished  \
# participant_id
# 5                      12        12             12       12        12
# 6                      13        13             13       13        13
# 7                      12        12             12       12        12
# 8                      12        12             12       12        12
# 9                      12        12             12       12        12
# 10                     12        12             12       12        12
# 11                     12        12             12       12        12
# 12                     12        12             12       12        12
# 13                     12        12             12       12        12
# 15                     12        12             12       12        12
# 16                     12        12             12       12        12
# 17                     12        12             12       12        12
# 18                     12        12             12       12        12
# 19                     12        12             12       12        12
# 20                     12        12             12       12        12
# 21                     12        12             12       12        12
# 22                     12        12             12       12        12
# 23                     12        12             12       12        12
#
#                 call_started  call_answered
# participant_id
# 5                         12             12
# 6                         13             13
# 7                         12             12
# 8                         12             12
# 9                         12             12
# 10                        12             12
# 11                        12             12
# 12                        12             12
# 13                        12             12
# 15                        12             12
# 16                        12             12
# 17                        12             12
# 18                        12             12
# 19                        12             12
# 20                        12             12
# 21                        12             12
# 22                        12             12
# 23                        12             12

# %%
# entry with participant_id 6 as one etrie more as possible
# so print the entries of participant_id 6 for visual check what happens there
print(df_runs_filtered.loc[df_runs_filtered.participant_id == 6])
# Out:
#       id  participant_id  custom_position_id  custom_direction_id  \
# 88    89               6                  27                    0
# 89    90               6                  28                    0
# 94    95               6                   0                   29
# 95    96               6                   0                   30
# 100  101               6                  31                    0
# 101  102               6                  32                    0
# 106  107               6                  33                    0
# 107  108               6                  34                    0
# 112  113               6                   0                   35
# 113  114               6                   0                   36
# 114  115               6                   0                   37
# 119  120               6                  38                    0
# 120  121               6                  39                    0
#
#     point_of_reference    placement    scenario avatar_gender  \
# 88        FixedInSpace  Interactive      Mobile          Male
# 89        FixedInSpace  Interactive      Mobile        Female
# 94         FieldOfView  Interactive  Stationary          Male
# 95         FieldOfView  Interactive  Stationary        Female
# 100           Relative  Interactive      Mobile          Male
# 101           Relative  Interactive      Mobile        Female
# 106           Relative  Interactive  Stationary          Male
# 107           Relative  Interactive  Stationary        Female
# 112        FieldOfView  Interactive      Mobile          Male
# 113        FieldOfView  Interactive      Mobile        Female
# 114        FieldOfView  Interactive      Mobile          Male
# 119       FixedInSpace  Interactive  Stationary        Female
# 120       FixedInSpace  Interactive  Stationary          Male
#
#                     started                finished            call_started  \
# 88   2019-1-12 15:37:45.400  2019-1-12 15:39:21.884  2019-1-12 15:37:46.914
# 89   2019-1-12 15:39:22.960   2019-1-12 15:41:11.69  2019-1-12 15:39:36.363
# 94    2019-1-12 16:4:22.836   2019-1-12 16:5:32.861    2019-1-12 16:4:25.82
# 95    2019-1-12 16:5:33.773    2019-1-12 16:6:20.97   2019-1-12 16:5:34.942
# 100  2019-1-12 16:24:49.739  2019-1-12 16:26:30.777   2019-1-12 16:24:59.68
# 101  2019-1-12 16:26:32.361  2019-1-12 16:27:15.723  2019-1-12 16:26:34.406
# 106   2019-1-12 16:45:3.126  2019-1-12 16:46:24.611   2019-1-12 16:45:5.972
# 107  2019-1-12 16:46:25.956   2019-1-12 16:47:7.392  2019-1-12 16:46:26.927
# 112   2019-1-12 17:2:12.891   2019-1-12 17:3:49.529   2019-1-12 17:2:15.921
# 113   2019-1-12 17:19:3.275  2019-1-12 17:20:50.169   2019-1-12 17:19:7.218
# 114  2019-1-12 17:20:52.491  2019-1-12 17:22:20.170  2019-1-12 17:20:55.101
# 119   2019-1-12 17:37:7.630   2019-1-12 17:40:5.727   2019-1-12 17:37:8.980
# 120   2019-1-12 17:40:6.742  2019-1-12 17:41:40.784   2019-1-12 17:40:8.784
#
#               call_answered
# 88   2019-1-12 15:38:48.638
# 89   2019-1-12 15:40:41.622
# 94    2019-1-12 16:4:58.581
# 95    2019-1-12 16:5:49.208
# 100  2019-1-12 16:25:58.194
# 101  2019-1-12 16:26:46.512
# 106  2019-1-12 16:45:53.169
# 107  2019-1-12 16:46:36.767
# 112    2019-1-12 17:3:17.56
# 113   2019-1-12 17:19:53.74
# 114  2019-1-12 17:21:44.244
# 119  2019-1-12 17:39:34.486
# 120   2019-1-12 17:41:7.525

# %%
df_runs_filtered['started'] = pd.to_datetime(df_runs_filtered['started'])
df_runs_filtered['finished'] = pd.to_datetime(df_runs_filtered['finished'])
df_runs_filtered['call_started'] = pd.to_datetime(df_runs_filtered['call_started'])
df_runs_filtered['call_answered'] = pd.to_datetime(df_runs_filtered['call_answered'])
df_runs_filtered.dtypes
# Out:
# id                              int64
# participant_id                  int64
# custom_position_id              int64
# custom_direction_id             int64
# point_of_reference             object
# placement                      object
# scenario                       object
# avatar_gender                  object
# started                datetime64[ns]
# finished               datetime64[ns]
# call_started           datetime64[ns]
# call_answered          datetime64[ns]
# dtype: object

# %%
import datetime, time
df_runs_filtered['total_time'] = (df_runs_filtered.finished - df_runs_filtered.started)
df_runs_filtered['call_started_time'] = (df_runs_filtered.call_started - df_runs_filtered.started)
df_runs_filtered['call_answered_time'] = (df_runs_filtered.call_answered - df_runs_filtered.call_started)
df_runs_filtered['total_time_seconds'] = df_runs_filtered['total_time'].dt.total_seconds()
df_runs_filtered['call_start_seconds'] = df_runs_filtered['call_started_time'].dt.total_seconds()
df_runs_filtered['call_answered_seconds'] = df_runs_filtered['call_answered_time'].dt.total_seconds()

print(df_runs_filtered)
# Out:
#       id  participant_id  custom_position_id  custom_direction_id  \
# 50    51               5                   0                   15
# 51    52               5                   0                   16
# 52    53               5                  17                    0
# 53    54               5                  18                    0
# 62    63               5                  19                    0
# ..   ...             ...                 ...                  ...
# 707    00:00:11.978000              43.291               0.921
# 716    00:01:14.998000             109.015               2.268
# 717    00:00:25.035000              55.589               0.838
#
#      call_answered_seconds
# 50                  39.412
# 51                  20.075
# 52                 102.431
# 53                  41.343
# 62                  48.656
# ..                     ...
# 705                 25.343
# 706                 26.835
# 707                 11.978
# 716                 74.998
# 717                 25.035
#
# [217 rows x 18 columns]

# %%
print(df_runs_filtered.loc[df_runs_filtered.participant_id == 6])
# Out:
#       id  participant_id  custom_position_id  custom_direction_id  \
# 88    89               6                  27                    0
# 89    90               6                  28                    0
# 94    95               6                   0                   29
# 95    96               6                   0                   30
# 100  101               6                  31                    0
# 101  102               6                  32                    0
# 106  107               6                  33                    0
# 107  108               6                  34                    0
# 112  113               6                   0                   35
# 113  114               6                   0                   36
# 114  115               6                   0                   37
# 119  120               6                  38                    0
# 120  121               6                  39                    0
#
#     point_of_reference    placement    scenario avatar_gender  \
# 88        FixedInSpace  Interactive      Mobile          Male
# 89        FixedInSpace  Interactive      Mobile        Female
# 94         FieldOfView  Interactive  Stationary          Male
# 95         FieldOfView  Interactive  Stationary        Female
# 100           Relative  Interactive      Mobile          Male
# 101           Relative  Interactive      Mobile        Female
# 106           Relative  Interactive  Stationary          Male
# 107           Relative  Interactive  Stationary        Female
# 112        FieldOfView  Interactive      Mobile          Male
# 113        FieldOfView  Interactive      Mobile        Female
# 114        FieldOfView  Interactive      Mobile          Male
# 119       FixedInSpace  Interactive  Stationary        Female
# 120       FixedInSpace  Interactive  Stationary          Male
#
#                     started                finished            call_started  \
# 88  2019-01-12 15:37:45.400 2019-01-12 15:39:21.884 2019-01-12 15:37:46.914
# 89  2019-01-12 15:39:22.960 2019-01-12 15:41:11.690 2019-01-12 15:39:36.363
# 94  2019-01-12 16:04:22.836 2019-01-12 16:05:32.861 2019-01-12 16:04:25.820
# 95  2019-01-12 16:05:33.773 2019-01-12 16:06:20.970 2019-01-12 16:05:34.942
# 100 2019-01-12 16:24:49.739 2019-01-12 16:26:30.777 2019-01-12 16:24:59.680
# 101 2019-01-12 16:26:32.361 2019-01-12 16:27:15.723 2019-01-12 16:26:34.406
# 106 2019-01-12 16:45:03.126 2019-01-12 16:46:24.611 2019-01-12 16:45:05.972
# 107 2019-01-12 16:46:25.956 2019-01-12 16:47:07.392 2019-01-12 16:46:26.927
# 112 2019-01-12 17:02:12.891 2019-01-12 17:03:49.529 2019-01-12 17:02:15.921
# 113 2019-01-12 17:19:03.275 2019-01-12 17:20:50.169 2019-01-12 17:19:07.218
# 114 2019-01-12 17:20:52.491 2019-01-12 17:22:20.170 2019-01-12 17:20:55.101
# 119 2019-01-12 17:37:07.630 2019-01-12 17:40:05.727 2019-01-12 17:37:08.980
# 120 2019-01-12 17:40:06.742 2019-01-12 17:41:40.784 2019-01-12 17:40:08.784
#
#               call_answered      total_time call_started_time  \
# 88  2019-01-12 15:38:48.638 00:01:36.484000   00:00:01.514000
# 89  2019-01-12 15:40:41.622 00:01:48.730000   00:00:13.403000
# 94  2019-01-12 16:04:58.581 00:01:10.025000   00:00:02.984000
# 95  2019-01-12 16:05:49.208 00:00:47.197000   00:00:01.169000
# 100 2019-01-12 16:25:58.194 00:01:41.038000   00:00:09.941000
# 101 2019-01-12 16:26:46.512 00:00:43.362000   00:00:02.045000
# 106 2019-01-12 16:45:53.169 00:01:21.485000   00:00:02.846000
# 107 2019-01-12 16:46:36.767 00:00:41.436000   00:00:00.971000
# 112 2019-01-12 17:03:17.560 00:01:36.638000   00:00:03.030000
# 113 2019-01-12 17:19:53.740 00:01:46.894000   00:00:03.943000
# 114 2019-01-12 17:21:44.244 00:01:27.679000   00:00:02.610000
# 119 2019-01-12 17:39:34.486 00:02:58.097000   00:00:01.350000
# 120 2019-01-12 17:41:07.525 00:01:34.042000   00:00:02.042000
#
#     call_answered_time  total_time_seconds  call_start_seconds  \
# 88     00:01:01.724000              96.484               1.514
# 89     00:01:05.259000             108.730              13.403
# 94     00:00:32.761000              70.025               2.984
# 95     00:00:14.266000              47.197               1.169
# 100    00:00:58.514000             101.038               9.941
# 101    00:00:12.106000              43.362               2.045
# 106    00:00:47.197000              81.485               2.846
# 107    00:00:09.840000              41.436               0.971
# 112    00:01:01.639000              96.638               3.030
# 113    00:00:46.522000             106.894               3.943
# 114    00:00:49.143000              87.679               2.610
# 119    00:02:25.506000             178.097               1.350
# 120    00:00:58.741000              94.042               2.042
#
#      call_answered_seconds
# 88                  61.724
# 89                  65.259
# 94                  32.761
# 95                  14.266
# 100                 58.514
# 101                 12.106
# 106                 47.197
# 107                  9.840
# 112                 61.639
# 113                 46.522
# 114                 49.143
# 119                145.506
# 120                 58.741

# %%
merged_positions = pd.merge(left=df_runs_filtered, right=df_positions, left_on='custom_position_id', right_on='id')
merged_directions = pd.merge(left=df_runs_filtered, right=df_positions, left_on='custom_direction_id', right_on='id')

# %%
print(df_runs_filtered.loc[df_runs_filtered.participant_id == 6])
# Out:
#       id  participant_id  custom_position_id  custom_direction_id  \
# 88    89               6                  27                    0
# 89    90               6                  28                    0
# 94    95               6                   0                   29
# 95    96               6                   0                   30
# 100  101               6                  31                    0
# 101  102               6                  32                    0
# 106  107               6                  33                    0
# 107  108               6                  34                    0
# 112  113               6                   0                   35
# 113  114               6                   0                   36
# 114  115               6                   0                   37
# 119  120               6                  38                    0
# 120  121               6                  39                    0
#
#     point_of_reference    placement    scenario avatar_gender  \
# 88        FixedInSpace  Interactive      Mobile          Male
# 89        FixedInSpace  Interactive      Mobile        Female
# 94         FieldOfView  Interactive  Stationary          Male
# 95         FieldOfView  Interactive  Stationary        Female
# 100           Relative  Interactive      Mobile          Male
# 101           Relative  Interactive      Mobile        Female
# 106           Relative  Interactive  Stationary          Male
# 107           Relative  Interactive  Stationary        Female
# 112        FieldOfView  Interactive      Mobile          Male
# 113    00:00:46.522000             106.894               3.943
# 114    00:00:49.143000              87.679               2.610
# 119    00:02:25.506000             178.097               1.350
# 120    00:00:58.741000              94.042               2.042
#
#      call_answered_seconds
# 88                  61.724
# 89                  65.259
# 94                  32.761
# 95                  14.266
# 100                 58.514
# 101                 12.106
# 106                 47.197
# 107                  9.840
# 112                 61.639
# 113                 46.522
# 114                 49.143
# 119                145.506
# 120                 58.741

# %%
print(merged_positions.loc[merged_positions.participant_id == 6])
# Out:
#     id_x  participant_id  custom_position_id  custom_direction_id  \
# 8     89               6                  27                    0
# 9     90               6                  28                    0
# 10   101               6                  31                    0
# 11   102               6                  32                    0
# 12   107               6                  33                    0
# 13   108               6                  34                    0
# 14   120               6                  38                    0
# 15   121               6                  39                    0
#
#    point_of_reference    placement    scenario avatar_gender  \
# 8        FixedInSpace  Interactive      Mobile          Male
# 9        FixedInSpace  Interactive      Mobile        Female
# 10           Relative  Interactive      Mobile          Male
# 11           Relative  Interactive      Mobile        Female
# 12           Relative  Interactive  Stationary          Male
# 13           Relative  Interactive  Stationary        Female
# 14       FixedInSpace  Interactive  Stationary        Female
# 15       FixedInSpace  Interactive  Stationary          Male
#
#                    started                finished  ...      total_time  \
# 8  2019-01-12 15:37:45.400 2019-01-12 15:39:21.884  ... 00:01:36.484000
# 9  2019-01-12 15:39:22.960 2019-01-12 15:41:11.690  ... 00:01:48.730000
# 10 2019-01-12 16:24:49.739 2019-01-12 16:26:30.777  ... 00:01:41.038000
# 11 2019-01-12 16:26:32.361 2019-01-12 16:27:15.723  ... 00:00:43.362000
# 12 2019-01-12 16:45:03.126 2019-01-12 16:46:24.611  ... 00:01:21.485000
# 13 2019-01-12 16:46:25.956 2019-01-12 16:47:07.392  ... 00:00:41.436000
# 14 2019-01-12 17:37:07.630 2019-01-12 17:40:05.727  ... 00:02:58.097000
# 15 2019-01-12 17:40:06.742 2019-01-12 17:41:40.784  ... 00:01:34.042000
#
#    call_started_time call_answered_time total_time_seconds call_start_seconds  \
# 8    00:00:01.514000    00:01:01.724000             96.484              1.514
# 9    00:00:13.403000    00:01:05.259000            108.730             13.403
# 10   00:00:09.941000    00:00:58.514000            101.038              9.941
# 11   00:00:02.045000    00:00:12.106000             43.362              2.045
# 12   00:00:02.846000    00:00:47.197000             81.485              2.846
# 13   00:00:00.971000    00:00:09.840000             41.436              0.971
# 14   00:00:01.350000    00:02:25.506000            178.097              1.350
# 15   00:00:02.042000    00:00:58.741000             94.042              2.042
#
#     call_answered_seconds  id_y         x     y         z
# 8                  61.724    27 -2.415244 -1.96  0.189838
# 9                  65.259    28 -2.617848 -1.96 -1.183044
# 10                 58.514    31  1.110212 -1.96 -0.214954
# 11                 12.106    32 -0.828157 -1.96 -1.119130
# 12                 47.197    33 -0.669470 -1.96 -1.492869
# 13                  9.840    34 -0.608028 -1.96 -1.561703
# 14                145.506    38  0.462316 -1.96 -3.098622
# 15                 58.741    39  0.521668 -1.96 -3.225307
#
# [8 rows x 22 columns]

# %%
print(merged_directions.loc[merged_directions.participant_id == 6])
# Out:
#    id_x  participant_id  custom_position_id  custom_direction_id  \
# 4    95               6                   0                   29
# 5    96               6                   0                   30
# 6   113               6                   0                   35
# 7   114               6                   0                   36
# 8   115               6                   0                   37
#
#   point_of_reference    placement    scenario avatar_gender  \
# 4        FieldOfView  Interactive  Stationary          Male
# 5        FieldOfView  Interactive  Stationary        Female
# 6        FieldOfView  Interactive      Mobile          Male
# 7        FieldOfView  Interactive      Mobile        Female
# 8        FieldOfView  Interactive      Mobile          Male
#
#                   started                finished  ...      total_time  \
# 4 2019-01-12 16:04:22.836 2019-01-12 16:05:32.861  ... 00:01:10.025000
# 5 2019-01-12 16:05:33.773 2019-01-12 16:06:20.970  ... 00:00:47.197000
# 6 2019-01-12 17:02:12.891 2019-01-12 17:03:49.529  ... 00:01:36.638000
# 7 2019-01-12 17:19:03.275 2019-01-12 17:20:50.169  ... 00:01:46.894000
# 8 2019-01-12 17:20:52.491 2019-01-12 17:22:20.170  ... 00:01:27.679000
#
#   call_started_time call_answered_time total_time_seconds call_start_seconds  \
# 4   00:00:02.984000    00:00:32.761000             70.025              2.984
# 5   00:00:01.169000    00:00:14.266000             47.197              1.169
# 6   00:00:03.030000    00:01:01.639000             96.638              3.030
# 7   00:00:03.943000    00:00:46.522000            106.894              3.943
# 8   00:00:02.610000    00:00:49.143000             87.679              2.610
#
#    call_answered_seconds  id_y           x           y           z
# 4                 32.761    29  354.269043    5.621902  358.239899
# 5                 14.266    30  351.439667    1.877005    1.126981
# 6                 61.639    35  356.017639  356.983429  349.257904
# 7                 46.522    36  355.730469  358.634827    1.049301
# 8                 49.143    37  356.154022    5.121446    6.655934
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
merged_directions.loc[(merged_positions.scenario == 'Mobile')].plot(kind='scatter',x='x',y='z',color='red')
plt.show()

# %%
merged_positions.loc[(merged_positions.scenario == 'Stationary') & (merged_positions.point_of_reference == 'Relative')].plot(kind='scatter',x='x',y='z',color='red')
plt.show()

# %%
merged_positions.loc[(merged_positions.scenario == 'Stationary') & (merged_positions.point_of_reference == 'FixedInSpace')].plot(kind='scatter',x='x',y='z',color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# generate 2 2d grids for the x & y bounds
#y, x = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))

z = (1 - x / 2. + x ** 5 + y ** 3) * np.exp(-x ** 2 - y ** 2)
# x and y are bounds, so z should be the value *inside* those bounds.
# Therefore, remove the last value from the z array.
z = z[:-1, :-1]
z_min, z_max = -np.abs(z).max(), np.abs(z).max()

fig, ax = plt.subplots()pytho

c = ax.pcolormesh(x, y, z, cmap='RdBu', vmin=z_min, vmax=z_max)
ax.set_title('pcolormesh')
# set the limits of the plot to the limits of the data
ax.axis([x.min(), x.max(), y.min(), y.max()])
fig.colorbar(c, ax=ax)

plt.show()
